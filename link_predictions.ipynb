# %%
import torch 

print(torch.__version__)
# Out:
# 2.1.0

# %%
# Install required packages
import os 

os.environ['TORCH'] = torch.__version__
# !pip install pyg-lib -f https://data.pyg.org/whl/nightly/torch-${TORCH}.html
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git

# !pip install sentence_transformers
# !pip3 install fuzzywuzzy[speedup]
# !pip install captum
# Out:
# Looking in links: https://data.pyg.org/whl/nightly/torch-2.1.0.html
# ERROR: Could not find a version that satisfies the requirement pyg-lib (from versions: none)
# ERROR: No matching distribution found for pyg-lib
# Collecting git+https://github.com/pyg-team/pytorch_geometric.git
#   Cloning https://github.com/pyg-team/pytorch_geometric.git to /private/var/folders/q5/6sf0p0j91czgynxtl5nljzh80000gn/T/pip-req-build-g1gsjwlq
#   Running command git clone --filter=blob:none --quiet https://github.com/pyg-team/pytorch_geometric.git /private/var/folders/q5/6sf0p0j91czgynxtl5nljzh80000gn/T/pip-req-build-g1gsjwlq
#   Resolved https://github.com/pyg-team/pytorch_geometric.git to commit 31b386b442f4800b35e963a90286d3486421bf7d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (4.66.1)
# Requirement already satisfied: numpy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (1.26.1)
# Requirement already satisfied: scipy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (1.11.3)
# Requirement already satisfied: jinja2 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (3.1.2)
# Requirement already satisfied: requests in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (2.31.0)
# Requirement already satisfied: pyparsing in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (3.1.1)
# Requirement already satisfied: scikit-learn in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (1.3.2)
# Requirement already satisfied: psutil>=5.8.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch_geometric==2.4.0) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from jinja2->torch_geometric==2.4.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->torch_geometric==2.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->torch_geometric==2.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->torch_geometric==2.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->torch_geometric==2.4.0) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from scikit-learn->torch_geometric==2.4.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from scikit-learn->torch_geometric==2.4.0) (3.2.0)
# Requirement already satisfied: sentence_transformers in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (4.35.0)
# Requirement already satisfied: tqdm in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (2.1.0)
# Requirement already satisfied: torchvision in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (0.16.0)
# Requirement already satisfied: numpy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (1.26.1)
# Requirement already satisfied: scikit-learn in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (1.3.2)
# Requirement already satisfied: scipy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: nltk in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sentence_transformers) (0.17.3)
# Requirement already satisfied: filelock in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.10.0)
# Requirement already satisfied: requests in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.0)
# Requirement already satisfied: click in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torchvision->sentence_transformers) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# zsh:1: no matches found: fuzzywuzzy[speedup]
# Collecting captum
#   Downloading captum-0.6.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from captum) (3.8.1)
# Requirement already satisfied: numpy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from captum) (1.26.1)
# Requirement already satisfied: torch>=1.6 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from captum) (2.1.0)
# Requirement already satisfied: filelock in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6->captum) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6->captum) (4.8.0)
# Requirement already satisfied: sympy in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6->captum) (1.12)
# Requirement already satisfied: networkx in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6->captum) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6->captum) (3.1.2)
# Requirement already satisfied: fsspec in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from torch>=1.6->captum) (2023.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from matplotlib->captum) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->captum) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->captum) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from jinja2->torch>=1.6->captum) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/aidenchang/miniforge3/envs/ml_final/lib/python3.9/site-packages (from sympy->torch>=1.6->captum) (1.3.0)
# Installing collected packages: captum
# Successfully installed captum-0.6.0

# %%
#Loading in our data
# !wget https://jmcauley.ucsd.edu/data/amazon_v2/categoryFilesSmall/Gift_Cards_5.json.gz --no-check-certificate
# !wget https://jmcauley.ucsd.edu/data/amazon_v2/categoryFilesSmall/Gift_Cards.csv --no-check-certificate
# !gzip -d Gift_Cards_5.json.gz
# !head Gift_Cards_5.json
# !head Gift_Cards.csv
# !wget https://datarepo.eng.ucsd.edu/mcauley_group/data/amazon_v2/metaFiles2/meta_Gift_Cards.json.gz --no-check-certificate
# !gzip -d meta_Gift_Cards.json.gz
# !head meta_Gift_Cards.json

# %%
import numpy as np
import torch
from sentence_transformers import SentenceTransformer
import random

# %%
# set the seed for reproducibility
seed = 224
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
##Defining classes

class Product:
  def __init__(self, title, asin, description, also_bought, categories):
    self.title = title #name, string
    self.asin = asin #string
    self.description = description #string
    # self.features = features # String[]
    self.also_bought = also_bought #asin[]
    self.categories = set(categories) #categories[]


  def __str__(self):
    return f"Product {self.title}"


class User:
  def __init__(self, reviewerID):
    self.reviewerID = reviewerID
    self.products_reviewed = []
    #maybe we can add the categories that they reviewed?

  def add_to_reviewed(self, product):
    self.products_reviewed.append(product)

  def __str__(self):
    return f"User {self.reviewerID} has reviewed {len(self.products_reviewed)} products"

# %%
import pandas as pd
import json

# reviews = pd.read_csv("Gift_Cards.csv")
review_data = []
review_name = 'Gift_Cards_5.json'
with open(review_name, 'r') as file:
    for line in file:
      review_data.append(json.loads(line))
file_metadata = []
metadata_link = "meta_Gift_Cards.json"
with open(metadata_link, 'r') as file:
    for line in file:
      file_metadata.append(json.loads(line))

# %%
products = {}
all_categories = {}
users = {}

def process_review_data(review):
  try:
    userID = review['reviewerID']
  except:
    print(review)
  if userID not in users:
    new_user = User(userID)
    users[userID] = new_user
  rating = int(review['overall'])
  users[userID].add_to_reviewed((review['asin'], rating))

def process_metadata(metadata):
  asin = metadata['asin']
  # features = metadata['features']
  also_bought = metadata['also_buy']
  description = metadata['description']
  categories = metadata['category']
  title = metadata['title']
  if asin not in products:
    new_product = Product(title, asin, description, also_bought, categories)
    products[asin] = new_product
  for category in categories:
    if category not in all_categories:
      all_categories[category] = Category(category)
    all_categories[category].add_to_category(asin)


def load_data():
  for line in review_data:
    process_review_data(line)
  for line in file_metadata:
    process_metadata(line)
